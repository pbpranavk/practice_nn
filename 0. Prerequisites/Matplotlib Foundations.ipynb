# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(np.array([0,1,2]), np.array([10,11,12]))
plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.title("My First Graph")b
# Out:
# Text(0.5, 1.0, 'My First Graph')

# %% [markdown]
# Forked from mrdbourke's repo https://github.com/mrdbourke/zero-to-mastery-ml/blob/master/section-2-data-science-and-ml-tools/introduction-to-matplotlib-video.ipynb

# %% [markdown]
# ## 1) 2 Ways of creating a plot
#  - plt.plot, plt.figure, plt.subplot (preferred way)

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([1,2,3,4], [11,22,33,44])

# %%
# OO version
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
## OO version with a slight difference
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot([1,2,3,4], [11,22,33,44])
plt.show()

# %%
## 2nd way
fig, ax = plt.subplots()
ax.plot([1,2,3,4], [11,22,33,44])

# %%
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %%
# A matplotlib workflow

# 0. Import and get matplotlib ready
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10,10))

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Sample Simple Plot", xlabel="x-axis", ylabel="y-axis")

# 5. Save & show
fig.savefig("./images/simple-plot.png")

# %% [markdown]
# ## 2) Types of plots (from numpy arrays & from pd data frames )
#  - .line, .scatter, .bar, .hist, .subplots
#  - preprocessing data in pd data frames before plotting them

# %%
x = np.linspace(0, 10, 100)

fig, ax = plt.subplots()
ax.plot(x, x**2)

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %%
nut_butter_prices = { "Almond Butter": 10,
                      "Peanut Butter": 8,
                      "Cashew Butter": 12
                    }

fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Dan's Nut Butter Store", ylabel="Price ($)")
# Out:
# [Text(0.5, 1.0, "Dan's Nut Butter Store"), Text(0, 0.5, 'Price ($)')]

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
x = np.random.randn(1000)

fig, ax = plt.subplots()
ax.hist(x)
# Out:
# (array([  9.,  34., 109., 209., 221., 216., 121.,  64.,  14.,   3.]),
#  array([-2.91961819, -2.29487331, -1.67012843, -1.04538355, -0.42063867,
#          0.20410621,  0.82885109,  1.45359597,  2.07834085,  2.70308573,
#          3.32783061]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.random(1000)

fig, ax = plt.subplots()
ax.hist(x)
# Out:
# (array([ 97.,  87., 110., 104., 105.,  96., 114., 110.,  91.,  86.]),
#  array([0.00306416, 0.10270825, 0.20235234, 0.30199643, 0.40164052,
#         0.50128461, 0.60092869, 0.70057278, 0.80021687, 0.89986096,
#         0.99950505]),
#  <BarContainer object of 10 artists>)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000))
# Out:
# (array([  4.,  25.,  75., 163., 237., 232., 162.,  74.,  21.,   7.]),
#  array([-3.08171078, -2.45515872, -1.82860666, -1.2020546 , -0.57550254,
#          0.05104952,  0.67760158,  1.30415364,  1.9307057 ,  2.55725776,
#          3.18380982]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

ax[0, 0].plot(x, x/2)
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(1000))
# Out:
# (array([  4.,  22.,  75., 176., 257., 238., 158.,  49.,  18.,   3.]),
#  array([-3.27066286, -2.58735832, -1.90405378, -1.22074924, -0.5374447 ,
#          0.14585984,  0.82916438,  1.51246892,  2.19577346,  2.87907801,
#          3.56238255]),
#  <BarContainer object of 10 artists>)

# %%
import pandas as pd

# %%
car_sales = pd.read_csv("./data/car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2020", periods=1000))

# %%
ts
# Out:
# 2020-01-01    0.256042
# 2020-01-02    0.037098
# 2020-01-03    0.376698
# 2020-01-04    0.721206
# 2020-01-05    2.038393
#                 ...
# 2022-09-22    0.580320
# 2022-09-23   -0.736940
# 2022-09-24    0.692466
# 2022-09-25   -0.136897
# 2022-09-26    0.597019
# Freq: D, Length: 1000, dtype: float64

# %%
ts.cumsum()
# Out:
# 2020-01-01     0.256042
# 2020-01-02     0.293140
# 2020-01-03     0.669838
# 2020-01-04     1.391044
# 2020-01-05     3.429437
#                 ...
# 2022-09-22    17.500029
# 2022-09-23    16.763088
# 2022-09-24    17.455554
# 2022-09-25    17.318657
# 2022-09-26    17.915677
# Freq: D, Length: 1000, dtype: float64

# %%
ts.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]", "")
car_sales
# Out:
# /var/folders/rb/43pnpks93vdb2495w14hz73h0000gn/T/ipykernel_97658/3073007673.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]", "")
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2020", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Sale Date", y="Total Sales")
# Out:
# <AxesSubplot:xlabel='Sale Date'>

# %%
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
x = np.random.rand(10, 4)
x
# Out:
# array([[0.43819904, 0.14303021, 0.67008604, 0.25874221],
#        [0.12662659, 0.50953178, 0.4889291 , 0.14827308],
#        [0.19096801, 0.11504182, 0.06931451, 0.44611278],
#        [0.79608215, 0.73239344, 0.98058238, 0.16659838],
#        [0.29454229, 0.34407937, 0.98639543, 0.00730767],
#        [0.2577327 , 0.84717882, 0.38814903, 0.33344159],
#        [0.79233903, 0.33860756, 0.89960767, 0.25551801],
#        [0.9854829 , 0.59040533, 0.38489399, 0.73969223],
#        [0.7231976 , 0.26281086, 0.05963143, 0.95184668],
#        [0.55882414, 0.54448936, 0.74236629, 0.8053747 ]])

# %%
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.438199  0.143030  0.670086  0.258742
# 1  0.126627  0.509532  0.488929  0.148273
# 2  0.190968  0.115042  0.069315  0.446113
# 3  0.796082  0.732393  0.980582  0.166598
# 4  0.294542  0.344079  0.986395  0.007308
# 5  0.257733  0.847179  0.388149  0.333442
# 6  0.792339  0.338608  0.899608  0.255518
# 7  0.985483  0.590405  0.384894  0.739692
# 8  0.723198  0.262811  0.059631  0.951847
# 9  0.558824  0.544489  0.742366  0.805375

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar")
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
car_sales["Odometer (KM)"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind ="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind ="hist", bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind ="hist", bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
heart_disease = pd.read_csv("./data/heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_disease["age"].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>],
#       dtype=object)

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots=False)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## 3) Plotting in OO fashion

# %%
over_50 = heart_disease[heart_disease["age"] > 50] 
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
over_50.plot(kind="scatter", x="age", y="chol", c="target", figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
fig, ax = plt.subplots(figsize=(10, 6))

over_50.plot(kind="scatter", 
             x="age",
             y="chol",
             c="target",ax=ax)

ax.set_xlim([45, 100])
# Out:
# (45.0, 100.0)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

scatter = ax.scatter(over_50["age"],
                    over_50["chol"], 
                    c=over_50["target"])

ax.set(title="Heart Disease and Cholestrol Levels",
      xlabel="Age",
      ylabel="Cholestrol")

ax.legend(*scatter.legend_elements(), title="Target")

# %%
fig, ax = plt.subplots(figsize=(10, 6))

scatter = ax.scatter(over_50["age"],
                    over_50["chol"], 
                    c=over_50["target"])

ax.set(title="Heart Disease and Cholestrol Levels",
      xlabel="Age",
      ylabel="Cholestrol")

ax.legend(*scatter.legend_elements(), title="Target")

ax.axhline(over_50["chol"].mean(), linestyle="--")

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 8))

scatter = ax0.scatter(over_50["age"],
                     over_50["chol"],
                     c=over_50["target"])

ax0.set(title="Heart Disease and Cholestrol Levels", ylabel="Cholestrol")
ax0.legend(*scatter.legend_elements(), title="Target")
ax0.axhline(over_50["chol"].mean(),color="b" , linestyle="--", label="Average")

scatter = ax1.scatter(over_50["age"], over_50["thalach"], c=over_50["target"])

ax1.set(title="Heart Disease and Max Heart Rate Levels", xlabel="Age", ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(), title="Target")
ax1.axhline(over_50["thalach"].mean(),color="b" , linestyle="--", label="Average")

fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# ## 4) Customizing plots
#  - .use() -> to change the grid style
#  - title, xlabel, ylabel
#  - axhline -> horizontal x line
#  - c & cmap -> color & color mpa
#  - set_xlim, set_ylim

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("seaborn-whitegrid")

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("seaborn")

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
plt.style.use("ggplot")

# %%
car_sales["Price"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.49118352,  0.66063206,  0.17487359,  0.23503346],
#        [ 1.65840116,  0.56534864,  0.99262731, -0.93768688],
#        [ 0.33471814,  0.67770393, -0.01814326, -1.70548869],
#        [ 0.53460775,  0.0924614 , -0.92620168, -1.33549531],
#        [ 0.11974984, -0.1213058 , -0.15472361, -0.03463971],
#        [-1.24989556, -0.80551266, -0.34605546, -0.11523987],
#        [-0.52098363, -0.65244302, -0.82467622, -0.4583017 ],
#        [ 0.4116091 ,  0.68562731,  1.64620858,  1.81112326],
#        [-0.6031136 , -1.47280665, -1.36823164,  1.00249185],
#        [ 0.47040303,  1.04765962,  0.33769   ,  0.47564806]])

# %%
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.491184  0.660632  0.174874  0.235033
# 1  1.658401  0.565349  0.992627 -0.937687
# 2  0.334718  0.677704 -0.018143 -1.705489
# 3  0.534608  0.092461 -0.926202 -1.335495
# 4  0.119750 -0.121306 -0.154724 -0.034640
# 5 -1.249896 -0.805513 -0.346055 -0.115240
# 6 -0.520984 -0.652443 -0.824676 -0.458302
# 7  0.411609  0.685627  1.646209  1.811123
# 8 -0.603114 -1.472807 -1.368232  1.002492
# 9  0.470403  1.047660  0.337690  0.475648

# %%
ax = df.plot(kind="bar")
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax = df.plot(kind="bar")
ax.set(title="Random Number Bar Graph from DataFrame",
      xlabel="Row Number",
       ylabel="Random Number"
      )
ax.legend().set_visible(True)

# %%
plt.style.use("seaborn-whitegrid")

# %%
fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(over_50["age"], 
                    over_50["chol"],
                    c=over_50["target"])

ax.set(title="Heart Disease and Cholestrol Levels",
      xlabel="Age",
      ylabel="Cholestrol")
ax.axhline(y=over_50["chol"].mean(),
          c="b",
          linestyle="--",
          label="Average")
ax.legend(*scatter.legend_elements(), title="Target")

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 8))

scatter = ax0.scatter(over_50["age"],
                     over_50["chol"],
                     c=over_50["target"],
                     cmap="winter")

ax0.set(title="Heart Disease and Cholestrol Levels", ylabel="Cholestrol")
ax0.legend(*scatter.legend_elements(), title="Target")
ax0.axhline(over_50["chol"].mean(),color="r" , linestyle="--", label="Average")


scatter = ax1.scatter(over_50["age"], over_50["thalach"], c=over_50["target"], cmap="winter")

ax1.set(title="Heart Disease and Max Heart Rate Levels", xlabel="Age", ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(), title="Target")
ax1.axhline(over_50["thalach"].mean(),color="b" , linestyle="--", label="Average")

fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 8))

scatter = ax0.scatter(over_50["age"],
                     over_50["chol"],
                     c=over_50["target"],
                     cmap="winter")

ax0.set(title="Heart Disease and Cholestrol Levels", ylabel="Cholestrol")
ax0.set_xlim([50, 80])
ax0.legend(*scatter.legend_elements(), title="Target")
ax0.axhline(over_50["chol"].mean(),color="r" , linestyle="--", label="Average")


scatter = ax1.scatter(over_50["age"], over_50["thalach"], c=over_50["target"], cmap="winter")

ax1.set(title="Heart Disease and Max Heart Rate Levels", xlabel="Age", ylabel="Max Heart Rate")
ax1.set_ylim([60, 200])
ax1.legend(*scatter.legend_elements(), title="Target")
ax1.axhline(over_50["thalach"].mean(),color="b" , linestyle="--", label="Average")

fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# ## 5) Saving Plot & Creating a plotting fuction
#  - 5.1 Save Plot
#      - .savefig
#  - 5.2 Creating a plotting func
#      - ```
#          def plotting_workflow(data):
#             # 1. Manipulating Data
#             # 2. Create plot
#             # 3. Plot data
#             # 4. Customize plot
#             # 5. Save Plot
#             # 6. Return Plot
#     return plot
#        ```

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 8))

scatter = ax0.scatter(over_50["age"],
                     over_50["chol"],
                     c=over_50["target"],
                     cmap="winter")

ax0.set(title="Heart Disease and Cholestrol Levels", ylabel="Cholestrol")
ax0.set_xlim([50, 80])
ax0.legend(*scatter.legend_elements(), title="Target")
ax0.axhline(over_50["chol"].mean(),color="r" , linestyle="--", label="Average")


scatter = ax1.scatter(over_50["age"], over_50["thalach"], c=over_50["target"], cmap="winter")

ax1.set(title="Heart Disease and Max Heart Rate Levels", xlabel="Age", ylabel="Max Heart Rate")
ax1.set_ylim([60, 200])
ax1.legend(*scatter.legend_elements(), title="Target")
ax1.axhline(over_50["thalach"].mean(),color="b" , linestyle="--", label="Average")

fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
fig

# %%
fig.savefig("./images/heart-disease-analysis.png")

# %%
#Reset figure
fig, ax = plt.subplots()

# %%
# Potential workflow func:

def plotting_workflow(data):
    # 1. Manipulate data
    
    #2. Create plot
    
    #3. Plot data
    
    #4. Customize plot
    
    #5. Save plot
    
    #6. Return plot
    
    return plot
